# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dfE = pd.read_csv('data/estadosEEUU.csv')

# %%
dfE
# Out:
#                 Type                       Name State           Capital  \
# 0              State                   Alabama     AL       Montgomery
# 1              State                    Alaska     AK           Juneau
# 2              State                   Arizona     AZ          Phoenix
# 3              State                  Arkansas     AR      Little Rock
# 4              State                California     CA       Sacramento
# 5              State                  Colorado     CO           Denver
# 6              State               Connecticut     CT         Hartford
# 7              State                  Delaware     DE            Dover
# 8              State                   Florida     FL      Tallahassee
# 9              State                   Georgia     GA          Atlanta
# 10             State                    Hawaii     HI         Honolulu
# 11             State                     Idaho     ID            Boise
# ...

# %%
dfE.keys()
# Out:
# Index(['Type', 'Name', 'State', 'Capital', 'Population (2015)',
#        'Population (2019)', 'area '],
#       dtype='object')

# %%
dfR= pd.read_csv('data/RankingU.csv')

# %%
dfR
# Out:
#                                          Name             Location  Rank  \
# 0                        Princeton University        Princeton, NJ     1
# 1                          Harvard University        Cambridge, MA     2
# 2                       University of Chicago          Chicago, IL     3
# 3                             Yale University        New Haven, CT     3
# 4                         Columbia University         New York, NY     5
# ..                                        ...                  ...   ...
# 226    University of Massachusetts--Dartmouth  North Dartmouth, MA   220
# 227         University of Missouri--St. Louis        St. Louis, MO   220
# 228  University of North Carolina--Greensboro       Greensboro, NC   220
# 229        University of Southern Mississippi      Hattiesburg, MS   220
# 230                     Utah State University            Logan, UT   220
#
#                                            Description Tuition and fees  \
# ...

# %%
dfR.keys()
# Out:
# Index(['Name', 'Location', 'Rank', 'Description', 'Tuition and fees',
#        'In-state', 'Undergrad Enrollment', 'State'],
#       dtype='object')

# %%
result = pd.merge(dfE, dfR, on="State")

# %%
result
# Out:
#                  Type                Name_x State      Capital  \
# 0               State              Alabama     AL  Montgomery
# 1               State              Alabama     AL  Montgomery
# 2               State              Alabama     AL  Montgomery
# 3               State              Alabama     AL  Montgomery
# 4               State               Alaska     AK      Juneau
# ..                ...                   ...   ...          ...
# 226  Federal District  District of Columbia    DC          NaN
# 227  Federal District  District of Columbia    DC          NaN
# 228  Federal District  District of Columbia    DC          NaN
# 229  Federal District  District of Columbia    DC          NaN
# 230  Federal District  District of Columbia    DC          NaN
#
#      Population (2015)  Population (2019)   area   \
# 0                  NaN          4903185.0   52420
# 1                  NaN          4903185.0   52420
# 2                  NaN          4903185.0   52420
# ...

# %%
#result.to_csv("data/result.csv")

# %%
plt.style.use("bmh")

# %%
fig, ax = plt.subplots()

# %%
x_values = result.State.unique()
y_values = result.State.value_counts().tolist()

# %%
my_plot = result.plot("Location", "Rank", kind="scatter")
plt.show() # no necesariamente en Jupyter Notebooks
